# %%
import pandas as pd
import os
import openpyxl

# %%
a = "X:\\Amar\\Python\\Study material\\Data analyst\\Data analyst project\\Netflix Dataset\\Netflix Dataset_excel.xlsx"

netflix_dataset = pd.read_excel(os.path.join(a), engine="openpyxl", sheet_name="Netflix_Dataset")
netflix_dataset
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                      1900-01-01 07:18:50
# 2         s3    Movie                      1900-01-01 23:58:50
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# ...

# %%
netflix_dataset.size   # size shows total values in dataset
# Out:
# 85679

# %%
netflix_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# <h1>Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.</h1>

# %%
netflix_dataset[netflix_dataset.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
netflix_dataset.drop_duplicates(inplace = True)
netflix_dataset
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                      1900-01-01 07:18:50
# 2         s3    Movie                      1900-01-01 23:58:50
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# ...

# %% [markdown]
# <h1>Task. 2) Is there any Null Value present in any column ? Show with Heat-map. </h1>

# %%
import seaborn as sns

netflix_dataset.isna().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(netflix_dataset.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1>Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ? </h1>

# %%
netflix_dataset.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show  0.03      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description
# 0  In a future where the elite inhabit an island ...

# %%
netflix_dataset[netflix_dataset["Title"].isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
netflix_dataset[netflix_dataset["Title"].str.contains("House of Cards")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-fba01ab93441> in <module>
# ----> 1 netflix_dataset[netflix_dataset["Title"].str.contains("House of Cards")]
#
# c:\Python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
# -> 2896         if com.is_bool_indexer(key):
#    2897             return self._getitem_bool_array(key)
#    2898
#
# c:\Python36\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# <h1>Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph. </h1>

# %%
netflix_dataset["year"] = pd.to_datetime(netflix_dataset["Release_Date"])

# %%
netflix_dataset["Year"] = netflix_dataset["year"].dt.year

# %%
netflix_dataset.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# year            datetime64[ns]
# Year                   float64
# dtype: object

# %%
netflix_dataset.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show  0.03      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description       year    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
netflix_dataset["year"].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: year, dtype: int64

# %%
netflix_dataset["year"].dt.year.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1>Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph. </h1>

# %%
netflix_dataset.groupby("Category")["Category"].count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(netflix_dataset["Category"])
# Out:
# c:\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# <h1>Q. 4) Show all the Movies that were released in year 2000. </h1>

# %%
netflix_dataset.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# year            datetime64[ns]
# dtype: object

# %%
netflix_dataset.head(2)
# Out:
#   Show_Id Category                Title           Director  \
# 0      s1  TV Show                 0.03                NaN
# 1      s2    Movie  1900-01-01 07:18:50  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       year
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
netflix_dataset[(netflix_dataset["Category"] == "Movie") & (netflix_dataset["year"] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# <h1>Q. 5) Show only the Titles of all TV Shows that were released in India only. </h1>

# %%
netflix_dataset[(netflix_dataset["Category"] == "TV Show") & (netflix_dataset["Country"] == "India")]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                          AkbarÂ Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# <h1>Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ? </h1>

# %%
netflix_dataset["Director"].value_counts().head(10)
# Out:
# RaÃºl Campos, Jan Suter    18
# Marcus Raboy               16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Jay Chapman                12
# Martin Scorsese            12
# Youssef Chahine            12
# Steven Spielberg           10
# David Dhawan                9
# Ryan Polito                 8
# Name: Director, dtype: int64

# %% [markdown]
# <h1>Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom". </h1>

# %%
netflix_dataset.head()
# Out:
#   Show_Id Category                Title           Director  \
# 0      s1  TV Show                 0.03                NaN
# 1      s2    Movie  1900-01-01 07:18:50  Jorge Michel Grau
# 2      s3    Movie  1900-01-01 23:58:50       Gilbert Chan
# 3      s4    Movie                    9        Shane Acker
# 4      s5    Movie                   21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# ...

# %%
netflix_dataset[(netflix_dataset["Category"] == "Movie") & (netflix_dataset["Type"] == "Comedies") | (netflix_dataset["Country"] == "United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                      89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# <h1>Q. 8) In how many movies/shows, Tom Cruise was cast ? </h1>

# %%
netflix_data_new = netflix_dataset.dropna()

# %%
netflix_data_new[netflix_data_new["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       year
# 3860  Through chance, human action, past history and... 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01

# %% [markdown]
# <h1>Q. 9) What are the different Ratings defined by Netflix ? </h1>

# %%
netflix_data_new["Rating"].nunique()
# Out:
# 14

# %%
# netflix_data_new["Rating"].unique()
netflix_data_new["Rating"].value_counts()
# Out:
# TV-MA       1666
# TV-14       1133
# R            654
# TV-PG        413
# PG-13        375
# PG           238
# TV-G          80
# TV-Y          71
# TV-Y7         69
# NR            62
# G             38
# UR             5
# TV-Y7-FV       3
# NC-17          2
# Name: Rating, dtype: int64

# %% [markdown]
# <h1>Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ? </h1>

# %%
netflix_data_new[(netflix_data_new["Category"] == "Movie") & (netflix_data_new["Rating"] == "TV-14") & (netflix_data_new["Country"] == "Canada")]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                    Jean-FranÃ§ois Blais
# ...

# %%
netflix_data_new["Year"] = netflix_data_new["year"].dt.year
# Out:
# C:\Users\amarn\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
netflix_data_new
# Out:
#      Show_Id Category                Title           Director  \
# 1         s2    Movie  1900-01-01 07:18:50  Jorge Michel Grau
# 2         s3    Movie  1900-01-01 23:58:50       Gilbert Chan
# 3         s4    Movie                    9        Shane Acker
# 4         s5    Movie                   21     Robert Luketic
# 5         s6  TV Show                   46        Serdar Akar
# ...      ...      ...                  ...                ...
# 7780   s7779    Movie           Zombieland    Ruben Fleischer
# 7782   s7781    Movie                  Zoo       Shlok Sharma
# 7783   s7782    Movie                 Zoom       Peter Hewitt
# 7784   s7783    Movie                 Zozo        Josef Fares
# 7785   s7784    Movie               Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# ...

# %% [markdown]
# <h1>Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ? </h1>

# %%
netflix_data_new["Year"] = pd.to_datetime(netflix_data_new["year"])
# Out:
# C:\Users\amarn\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
netflix_data_new.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# year            datetime64[ns]
# Year                     int64
# dtype: object

# %%
netflix_data_new.head(2)
# Out:
#   Show_Id Category                Title           Director  \
# 1      s2    Movie  1900-01-01 07:18:50  Jorge Michel Grau
# 2      s3    Movie  1900-01-01 23:58:50       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       year  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %% [markdown]
# <h4>ONE record we will get</h1>

# %%
netflix_data_new[(netflix_data_new["Category"] == "TV Show") & (netflix_data_new["Rating"] == "R") & (netflix_data_new["Year"] > 2018)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year, Year]
# Index: []

# %% [markdown]
# <h1>Q. 10) What is the maximum duration of a Movie/Show on Netflix ? </h1>

# %%
netflix_data_new["Duration"].unique()
netflix_data_new["Duration"]
# Out:
# 1         93 min
# 2         78 min
# 3         80 min
# 4        123 min
# 5       1 Season
#           ...
# 7780      88 min
# 7782      94 min
# 7783      88 min
# 7784      99 min
# 7785     111 min
# Name: Duration, Length: 4809, dtype: object

# %%
netflix_data_new[["Minute", "Unit"]] = netflix_data_new["Duration"].str.split(" ", expand=True)
# Out:
# c:\Python36\lib\site-packages\pandas\core\frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
netflix_data_new.head()
# Out:
#   Show_Id Category                Title           Director  \
# 1      s2    Movie  1900-01-01 07:18:50  Jorge Michel Grau
# 2      s3    Movie  1900-01-01 23:58:50       Gilbert Chan
# 3      s4    Movie                    9        Shane Acker
# 4      s5    Movie                   21     Robert Luketic
# 5      s6  TV Show                   46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal BeÅŸikÃ§ioÄŸlu, Yasemin Allen, Melis Bir...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# ...

# %%
netflix_data_new["Minute"].max()  #mean show infinite becase it is dtype is object
# Out:
# '99'

# %% [markdown]
# <h1>Q. 11) Which individual country has the Highest No. of TV Shows ? </h1>

# %%
tv_show_data = netflix_data_new[netflix_data_new["Category"] == "TV Show"]
tv_show_data
# Out:
#      Show_Id Category            Title            Director  \
# 5         s6  TV Show               46         Serdar Akar
# 132     s133  TV Show        7 (Seven)         Nizar Shafi
# 218     s219  TV Show  A Queen Is Born        Carla Barros
# 260     s261  TV Show         A.I.C.O.       Kazuya Murata
# 276     s277  TV Show     Abby Hatcher         Kyran Kelly
# ...      ...      ...              ...                 ...
# 7387   s7386  TV Show          Valeria       Inma Torrente
# 7402   s7401  TV Show           Velvet        Carlos Sedes
# 7494   s7493  TV Show   Watership Down          Noam Murro
# 7668   s7667  TV Show    World of Winx      Iginio Straffi
# 7723   s7722  TV Show              You  Lee Toland Krieger
#
#                                                    Cast  \
# 5     Erdal BeÅŸikÃ§ioÄŸlu, Yasemin Allen, Melis Bir...
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...
# 218                       Gloria Groove, Alexia Twister
# ...

# %%
tv_show_data["Country"].value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# South Korea                                                      10
# Japan                                                            10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Thailand                                                          3
# Canada                                                            3
# France                                                            3
# Nigeria                                                           3
# Denmark                                                           2
# ...

# %%
tv_show_data["Country"].value_counts().head(1)
# Out:
# United States    27
# Name: Country, dtype: int64

# %% [markdown]
# <h1>Q. 12) How can we sort the dataset by Year ? </h1>

# %%
netflix_data_new.sort_values(by="Year", ascending=False)
# Out:
#      Show_Id Category                        Title  \
# 2269   s2270    Movie                   Fred Claus
# 2349   s2350    Movie                    Gangaajal
# 6248   s6248    Movie           The Creative Brain
# 1673   s1674    Movie                  Death of Me
# 7147   s7146    Movie  Tony Parker: The Final Shot
# ...      ...      ...                          ...
# 2041   s2042    Movie                Even the Rain
# 3840   s3841    Movie  Mad Ron's Prevues from Hell
# 3248   s3249    Movie      Just Another Love Story
# 5766   s5766    Movie                     Splatter
# 7115   s7114    Movie         To and From New York
#
#                              Director  \
# 2269                     David Dobkin
# 2349                      Prakash Jha
# 6248  Jennifer Beamish, Toby Trackman
# 1673              Darren Lynn Bousman
# 7147                    Florent Bodin
# ...                               ...
# 2041                  IcÃ­ar BollaÃ­n
# ...

# %% [markdown]
# <h1>Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'. </h1>

# %%
netflix_data_new[(netflix_data_new["Category"] == "Movie") & (netflix_data_new["Type"] == "Dramas")]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# <h1>Below Query write DOUBLE QUOTES ("Kids' TV") to avoid error</h1>

# %%
netflix_data_new[(netflix_data_new["Category"] == "TV Show") & (netflix_data_new["Type"] == "Kids' TV")]
# Out:
#      Show_Id Category                                       Title  \
# 276     s277  TV Show                                Abby Hatcher
# 3582   s3583  TV Show            Lego Friends: Girls on a Mission
# 6204   s6204  TV Show  The Cat in the Hat Knows a Lot About That!
# 7668   s7667  TV Show                               World of Winx
#
#                         Director  \
# 276                  Kyran Kelly
# 3582  Andrew Tan, Stephen Murray
# 6204            Tony Collingwood
# 7668              Iginio Straffi
#
#                                                    Cast  \
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# 3582  Jasmine St. Clair, Allegra Clark, Rosamund Mar...
# 6204  Martin Short, Alexa Torrington, Jacob Ewaniuk,...
# 7668  Haven Paschall, Alysha Deslorieux, Jessica Paq...
#
#                                     Country      Release_Date Rating  \
# 276                   United States, Canada      July 1, 2020   TV-Y
# ...

# %%
netflix_data_new[(netflix_data_new["Category"] == "Movie") & (netflix_data_new["Type"] == "Dramas") | (netflix_data_new["Category"] == "TV Show") & (netflix_data_new["Type"] == "Kids' TV")]
# Out:
#      Show_Id Category                       Title          Director  \
# 4         s5    Movie                          21    Robert Luketic
# 7         s8    Movie                         187    Kevin Reynolds
# 170     s171    Movie                A Family Man     Mark Williams
# 232     s233    Movie  A Stoning in Fulham County     Larry Elikann
# 276     s277  TV Show                Abby Hatcher       Kyran Kelly
# ...      ...      ...                         ...               ...
# 7422   s7421    Movie                     Villain  Philip Barantini
# 7449   s7448    Movie                         VS.          Ed Lilly
# 7465   s7464    Movie                   Wakefield     Robin Swicord
# 7480   s7479    Movie                   War Horse  Steven Spielberg
# 7668   s7667  TV Show               World of Winx    Iginio Straffi
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
